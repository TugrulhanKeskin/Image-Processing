# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Resmi içe aktar

# %%
img = cv2.imread("img1.JPG")
img =cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
#RESMIN siyah beyaz olması değil renklerin skada ifade edilmesi anlamına geliyor , siyahlar 0 beyazlar 255 arasında değişiyor 

plt.figure()
plt.imshow(img, cmap ="gray" ) #siyah beyaz görebilmek için color map ekledik
plt.axis("off")
plt.show()

# %% [markdown]
# ### Eşikleme
# Resmi detaylardan arındırıp ana hatlarını ortaya çıkarmak için kullanılır

# %%
_, thresh_img = cv2.threshold(img, thresh = 60, maxval = 255, type = cv2.THRESH_BINARY)

plt.figure()
plt.imshow(thresh_img, cmap ="gray")
plt.axis("off")
plt.show()

# %%
#aynı kodun sonuna INV(invert) eklediğimizde 
_, thresh_img2 = cv2.threshold(img, thresh = 60, maxval = 255, type = cv2.THRESH_BINARY_INV)

plt.figure()
plt.imshow(thresh_img2, cmap ="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# ### Adaptive Threshold
# Üstte kullandıklarımızda global tresholding değerleri kullandık fakat kullanıcağımız görüntünün farklı yerlerinde farklı aydınlatma değerleri varsa adaptive tresholding kullanılmalı
#
# Adaptive tresholdingte aynı görüntüniü farklı bölgeleri için farklı eşik değerleri kullanarak , aydınlatması farklı bölgelerde avantaj sağlıyor.

# %% [markdown]
# - Kodun açıklaması
#     - adaptive tresholding
#     #ADAPTIVE_THRESH_MEAN_C, kullanıcağımız eşikleme algoritması yöntemi c sabiti ortalamadan ya da ağırlıklı ortalamadan çıkarılabilecek bi değer normalde pozitif ama 0 - negatif de alınabilir.
#     - #cv2.THRESH_BINARY thresh holdun tipi nasıl eşikleme yapıcaz , eşiklemeden sonra piksellerin hangi değerleri alabileceğini belirten ifade
#     - #11 blok size pksel için eşik değeri hesaplamak için kullanılıyor bi piksel topluluğuna göre eşikleme yapıyorduk bu topluluğun 11 komşusuna bakıyoruz diyebiliriz

# %%
thresh_img3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11,8)

plt.figure()
plt.imshow(thresh_img3, cmap="gray")
plt.axis("off")
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
first_plot = fig.add_subplot(1,2,1)
first_plot.imshow(thresh_img, cmap="gray")
first_plot.axis("off")
first_plot.set_title("thresholding")

second_plot = fig.add_subplot(1,2,2)
second_plot.imshow(thresh_img3, cmap="gray")
second_plot.axis("off")
second_plot.set_title("adaptive thresholding")
# Out:
# Text(0.5, 1.0, 'adaptive thresholding')
